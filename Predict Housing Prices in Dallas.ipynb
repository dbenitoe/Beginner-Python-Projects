# %%
US_CPI = "C:\\Users\\dbeni\\Downloads\\house_prices\\CPIAUCSL.csv" 
Rental_Vacancy = "C:\\Users\\dbeni\\Downloads\\house_prices\\RRVRUSQ156N.csv"
Mortgage_Rates = "C:\\Users\\dbeni\\Downloads\\house_prices\\MORTGAGE30US.csv"
Median_Sale_Price = "C:\\Users\\dbeni\\Downloads\\house_prices\\Metro_median_sale_price_uc_sfrcondo_week.csv"
Zillow_Home_Value = "C:\\Users\\dbeni\Downloads\\house_prices\\Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv"

# %%
import pandas as pd

fed_files = [Mortgage_Rates,Rental_Vacancy,US_CPI]

dfs = [pd.read_csv(f , parse_dates=True, index_col=0) for f in fed_files]

# %%
dfs[0]
# Out:
#             MORTGAGE30US
# DATE
# 1971-04-02          7.33
# 1971-04-09          7.31
# 1971-04-16          7.31
# 1971-04-23          7.31
# 1971-04-30          7.29
# ...                  ...
# 2022-07-14          5.51
# 2022-07-21          5.54
# 2022-07-28          5.30
# 2022-08-04          4.99
# 2022-08-11          5.22
#
# [2681 rows x 1 columns]

# %%
dfs[1]
# Out:
#             RRVRUSQ156N
# DATE
# 1956-01-01          6.2
# 1956-04-01          5.9
# 1956-07-01          6.3
# 1956-10-01          5.8
# 1957-01-01          5.3
# ...                 ...
# 2021-04-01          6.2
# 2021-07-01          5.8
# 2021-10-01          5.6
# 2022-01-01          5.8
# 2022-04-01          5.6
#
# [266 rows x 1 columns]

# %%
dfs[2]
# Out:
#             CPIAUCSL
# DATE
# 1947-01-01    21.480
# 1947-02-01    21.620
# 1947-03-01    22.000
# 1947-04-01    22.000
# 1947-05-01    21.950
# ...              ...
# 2022-03-01   287.708
# 2022-04-01   288.663
# 2022-05-01   291.474
# 2022-06-01   295.328
# 2022-07-01   295.271
#
# [907 rows x 1 columns]

# %%
fed_data = pd.concat(dfs, axis= 1)

# %%
fed_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 1947-01-01           NaN          NaN     21.48
# 1947-02-01           NaN          NaN     21.62
# 1947-03-01           NaN          NaN     22.00
# 1947-04-01           NaN          NaN     22.00
# 1947-05-01           NaN          NaN     21.95
# ...                  ...          ...       ...
# 2022-07-14          5.51          NaN       NaN
# 2022-07-21          5.54          NaN       NaN
# 2022-07-28          5.30          NaN       NaN
# 2022-08-04          4.99          NaN       NaN
# 2022-08-11          5.22          NaN       NaN
#
# [3507 rows x 3 columns]

# %%
fed_data.tail(50)
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2021-11-01           NaN          NaN   278.524
# 2021-11-04          3.09          NaN       NaN
# 2021-11-10          2.98          NaN       NaN
# 2021-11-18          3.10          NaN       NaN
# 2021-11-24          3.10          NaN       NaN
# 2021-12-01           NaN          NaN   280.126
# 2021-12-02          3.11          NaN       NaN
# 2021-12-09          3.10          NaN       NaN
# 2021-12-16          3.12          NaN       NaN
# 2021-12-23          3.05          NaN       NaN
# 2021-12-30          3.11          NaN       NaN
# 2022-01-01           NaN          5.8   281.933
# 2022-01-06          3.22          NaN       NaN
# 2022-01-13          3.45          NaN       NaN
# 2022-01-20          3.56          NaN       NaN
# 2022-01-27          3.55          NaN       NaN
# 2022-02-01           NaN          NaN   284.182
# 2022-02-03          3.55          NaN       NaN
# 2022-02-10          3.69          NaN       NaN
# 2022-02-17          3.92          NaN       NaN
# 2022-02-24          3.89          NaN       NaN
# 2022-03-01           NaN          NaN   287.708
# 2022-03-03          3.76          NaN       NaN
# 2022-03-10          3.85          NaN       NaN
# 2022-03-17          4.16          NaN       NaN
# 2022-03-24          4.42          NaN       NaN
# 2022-03-31          4.67          NaN       NaN
# 2022-04-01           NaN          5.6   288.663
# 2022-04-07          4.72          NaN       NaN
# 2022-04-14          5.00          NaN       NaN
# 2022-04-21          5.11          NaN       NaN
# 2022-04-28          5.10          NaN       NaN
# 2022-05-01           NaN          NaN   291.474
# 2022-05-05          5.27          NaN       NaN
# 2022-05-12          5.30          NaN       NaN
# 2022-05-19          5.25          NaN       NaN
# 2022-05-26          5.10          NaN       NaN
# 2022-06-01           NaN          NaN   295.328
# 2022-06-02          5.09          NaN       NaN
# 2022-06-09          5.23          NaN       NaN
# 2022-06-16          5.78          NaN       NaN
# 2022-06-23          5.81          NaN       NaN
# 2022-06-30          5.70          NaN       NaN
# 2022-07-01           NaN          NaN   295.271
# 2022-07-07          5.30          NaN       NaN
# 2022-07-14          5.51          NaN       NaN
# 2022-07-21          5.54          NaN       NaN
# 2022-07-28          5.30          NaN       NaN
# 2022-08-04          4.99          NaN       NaN
# 2022-08-11          5.22          NaN       NaN

# %%
# We need to fix this chart by using forward filling.

fed_data= fed_data.ffill()

# %%
fed_data.tail(50)
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2021-11-01          3.14          5.6   278.524
# 2021-11-04          3.09          5.6   278.524
# 2021-11-10          2.98          5.6   278.524
# 2021-11-18          3.10          5.6   278.524
# 2021-11-24          3.10          5.6   278.524
# 2021-12-01          3.10          5.6   280.126
# 2021-12-02          3.11          5.6   280.126
# 2021-12-09          3.10          5.6   280.126
# 2021-12-16          3.12          5.6   280.126
# 2021-12-23          3.05          5.6   280.126
# 2021-12-30          3.11          5.6   280.126
# 2022-01-01          3.11          5.8   281.933
# 2022-01-06          3.22          5.8   281.933
# 2022-01-13          3.45          5.8   281.933
# 2022-01-20          3.56          5.8   281.933
# 2022-01-27          3.55          5.8   281.933
# 2022-02-01          3.55          5.8   284.182
# 2022-02-03          3.55          5.8   284.182
# 2022-02-10          3.69          5.8   284.182
# 2022-02-17          3.92          5.8   284.182
# 2022-02-24          3.89          5.8   284.182
# 2022-03-01          3.89          5.8   287.708
# 2022-03-03          3.76          5.8   287.708
# 2022-03-10          3.85          5.8   287.708
# 2022-03-17          4.16          5.8   287.708
# 2022-03-24          4.42          5.8   287.708
# 2022-03-31          4.67          5.8   287.708
# 2022-04-01          4.67          5.6   288.663
# 2022-04-07          4.72          5.6   288.663
# 2022-04-14          5.00          5.6   288.663
# 2022-04-21          5.11          5.6   288.663
# 2022-04-28          5.10          5.6   288.663
# 2022-05-01          5.10          5.6   291.474
# 2022-05-05          5.27          5.6   291.474
# 2022-05-12          5.30          5.6   291.474
# 2022-05-19          5.25          5.6   291.474
# 2022-05-26          5.10          5.6   291.474
# 2022-06-01          5.10          5.6   295.328
# 2022-06-02          5.09          5.6   295.328
# 2022-06-09          5.23          5.6   295.328
# 2022-06-16          5.78          5.6   295.328
# 2022-06-23          5.81          5.6   295.328
# 2022-06-30          5.70          5.6   295.328
# 2022-07-01          5.70          5.6   295.271
# 2022-07-07          5.30          5.6   295.271
# 2022-07-14          5.51          5.6   295.271
# 2022-07-21          5.54          5.6   295.271
# 2022-07-28          5.30          5.6   295.271
# 2022-08-04          4.99          5.6   295.271
# 2022-08-11          5.22          5.6   295.271

# %%
zillow_files = [Median_Sale_Price,Zillow_Home_Value]

# %%
dfs = [pd.read_csv(f)for f in zillow_files]

# %%
dfs[0]
# Out:
#     RegionID  SizeRank                          RegionName RegionType  \
# 0     102001         0                       United States    Country
# 1     394913         1                        New York, NY        Msa
# 2     753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3     394463         3                         Chicago, IL        Msa
# 4     394514         4               Dallas-Fort Worth, TX        Msa
# ..       ...       ...                                 ...        ...
# 79    394528        90                   Daytona Beach, FL        Msa
# 80    394531        91                      Des Moines, IA        Msa
# 81    395006       100                           Provo, UT        Msa
# 82    394549       104                          Durham, NC        Msa
# 83    394602       159                    Fort Collins, CO        Msa
#
#    StateName  2008-02-02  2008-02-09  2008-02-16  2008-02-23  2008-03-01  ...  \
# 0        NaN    190000.0    190000.0    193000.0    189900.0    194900.0  ...
# 1         NY    400000.0    418250.0    420000.0    420000.0    400000.0  ...
# 2         CA    497500.0    515000.0    520000.0    525000.0    498250.0  ...
# 3         IL    245000.0    245000.0    251000.0    255000.0    255000.0  ...
# 4         TX    144250.0    148900.0    139000.0    143700.0    145900.0  ...
# ..       ...         ...         ...         ...         ...         ...  ...
# 79        FL         NaN    170000.0    182400.0    170000.0    170000.0  ...
# 80        IA    138000.0    160000.0    150000.0    151750.0    154500.0  ...
# 81        UT         NaN    206000.0    215500.0    210000.0    210000.0  ...
# 82        NC    210000.0    170000.0    170500.0    197500.0    180000.0  ...
# 83        CO         NaN    255000.0    205000.0    229900.0    235000.0  ...
#
#     2022-05-07  2022-05-14  2022-05-21  2022-05-28  2022-06-04  2022-06-11  \
# 0     369900.0    370000.0    370000.0    375000.0    375000.0    370000.0
# 1     550000.0    555000.0    550000.0    575000.0    575000.0    578000.0
# 2     914000.0    925000.0    925000.0    951000.0    950000.0    920500.0
# 3     315000.0    310000.0    315500.0    315000.0    330000.0    324950.0
# 4     422000.0    430000.0    430000.0    425000.0    440000.0    425000.0
# ..         ...         ...         ...         ...         ...         ...
# 79    340500.0    345000.0    327700.0    345000.0    350000.0    343250.0
# 80    270000.0    285250.0    295000.0    273450.0    301000.0    290000.0
# 81    527000.0    540000.0    535000.0    552500.0    543750.0    571000.0
# 82    456000.0    450000.0    428500.0    480000.0    465000.0    440000.0
# 83    575000.0    585250.0    575000.0    550000.0    569900.0    560000.0
#
#     2022-06-18  2022-06-25  2022-07-02  2022-07-09
# 0     375000.0    370000.0    370000.0    362500.0
# 1     590000.0    582000.0    585000.0    595000.0
# 2     925000.0    900000.0    900500.0    906000.0
# 3     335000.0    325000.0    325000.0    315000.0
# 4     427750.0    426000.0    420000.0    420000.0
# ..         ...         ...         ...         ...
# 79    359900.0    352000.0    336000.0    342990.0
# 80    300900.0    281900.0    289250.0    280000.0
# 81    530300.0    569900.0    539950.0    572500.0
# 82    450250.0    416000.0    465000.0    435250.0
# 83    595000.0    550000.0    556058.0    595000.0
#
# [84 rows x 759 columns]

# %%
dfs = [pd.DataFrame(df.iloc[4,5:]) for df in dfs]

# %%
dfs[1]
# Out:
#                         4
# 1996-01-31  113283.512989
# 1996-02-29  113199.113561
# 1996-03-31  113519.423633
# 1996-04-30  114048.064719
# 1996-05-31  114287.444295
# ...                   ...
# 2022-03-31  376522.090399
# 2022-04-30  391696.585402
# 2022-05-31  399613.324087
# 2022-06-30  401254.775442
# 2022-07-31  396903.773679
#
# [319 rows x 1 columns]

# %%
dfs[0]
# Out:
#                    4
# 2008-02-02  144250.0
# 2008-02-09  148900.0
# 2008-02-16  139000.0
# 2008-02-23  143700.0
# 2008-03-01  145900.0
# ...              ...
# 2022-06-11  425000.0
# 2022-06-18  427750.0
# 2022-06-25  426000.0
# 2022-07-02  420000.0
# 2022-07-09  420000.0
#
# [754 rows x 1 columns]

# %%
for df in dfs:
    df.index = pd.to_datetime(df.index)
    df['month']= df.index.to_period('M')

# %%
dfs[1]
# Out:
#                         4    month
# 1996-01-31  113283.512989  1996-01
# 1996-02-29  113199.113561  1996-02
# 1996-03-31  113519.423633  1996-03
# 1996-04-30  114048.064719  1996-04
# 1996-05-31  114287.444295  1996-05
# ...                   ...      ...
# 2022-03-31  376522.090399  2022-03
# 2022-04-30  391696.585402  2022-04
# 2022-05-31  399613.324087  2022-05
# 2022-06-30  401254.775442  2022-06
# 2022-07-31  396903.773679  2022-07
#
# [319 rows x 2 columns]

# %%
price_data = dfs[0].merge(dfs[1], on ='month')

# %%
price_data.index = dfs[0].index

# %%
price_data
# Out:
#                  4_x    month            4_y
# 2008-02-02  144250.0  2008-02  157110.334849
# 2008-02-09  148900.0  2008-02  157110.334849
# 2008-02-16  139000.0  2008-02  157110.334849
# 2008-02-23  143700.0  2008-02  157110.334849
# 2008-03-01  145900.0  2008-03  157027.222613
# ...              ...      ...            ...
# 2022-06-11  425000.0  2022-06  401254.775442
# 2022-06-18  427750.0  2022-06  401254.775442
# 2022-06-25  426000.0  2022-06  401254.775442
# 2022-07-02  420000.0  2022-07  396903.773679
# 2022-07-09  420000.0  2022-07  396903.773679
#
# [754 rows x 3 columns]

# %%
del price_data['month']
price_data.columns = ['price', 'value']

# %%
price_data
# Out:
#                price          value
# 2008-02-02  144250.0  157110.334849
# 2008-02-09  148900.0  157110.334849
# 2008-02-16  139000.0  157110.334849
# 2008-02-23  143700.0  157110.334849
# 2008-03-01  145900.0  157027.222613
# ...              ...            ...
# 2022-06-11  425000.0  401254.775442
# 2022-06-18  427750.0  401254.775442
# 2022-06-25  426000.0  401254.775442
# 2022-07-02  420000.0  396903.773679
# 2022-07-09  420000.0  396903.773679
#
# [754 rows x 2 columns]

# %%
fed_data = fed_data.dropna()

# %%
fed_data.tail(20)
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2022-04-21          5.11          5.6   288.663
# 2022-04-28          5.10          5.6   288.663
# 2022-05-01          5.10          5.6   291.474
# 2022-05-05          5.27          5.6   291.474
# 2022-05-12          5.30          5.6   291.474
# 2022-05-19          5.25          5.6   291.474
# 2022-05-26          5.10          5.6   291.474
# 2022-06-01          5.10          5.6   295.328
# 2022-06-02          5.09          5.6   295.328
# 2022-06-09          5.23          5.6   295.328
# 2022-06-16          5.78          5.6   295.328
# 2022-06-23          5.81          5.6   295.328
# 2022-06-30          5.70          5.6   295.328
# 2022-07-01          5.70          5.6   295.271
# 2022-07-07          5.30          5.6   295.271
# 2022-07-14          5.51          5.6   295.271
# 2022-07-21          5.54          5.6   295.271
# 2022-07-28          5.30          5.6   295.271
# 2022-08-04          4.99          5.6   295.271
# 2022-08-11          5.22          5.6   295.271

# %%
from datetime import timedelta
fed_data.index = fed_data.index + timedelta(days=2)

# %%
fed_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 1971-04-04          7.33          5.3    40.100
# 1971-04-11          7.31          5.3    40.100
# 1971-04-18          7.31          5.3    40.100
# 1971-04-25          7.31          5.3    40.100
# 1971-05-02          7.29          5.3    40.100
# ...                  ...          ...       ...
# 2022-07-16          5.51          5.6   295.271
# 2022-07-23          5.54          5.6   295.271
# 2022-07-30          5.30          5.6   295.271
# 2022-08-06          4.99          5.6   295.271
# 2022-08-13          5.22          5.6   295.271
#
# [3215 rows x 3 columns]

# %%
price_data = fed_data.merge(price_data, left_index=True, right_index = True)

# %%
price_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL     price          value
# 2008-02-02          5.68         10.1   212.174  144250.0  157110.334849
# 2008-02-09          5.67         10.1   212.687  148900.0  157110.334849
# 2008-02-16          5.72         10.1   212.687  139000.0  157110.334849
# 2008-02-23          6.04         10.1   212.687  143700.0  157110.334849
# 2008-03-01          6.24         10.1   212.687  145900.0  157027.222613
# ...                  ...          ...       ...       ...            ...
# 2022-06-11          5.23          5.6   295.328  425000.0  401254.775442
# 2022-06-18          5.78          5.6   295.328  427750.0  401254.775442
# 2022-06-25          5.81          5.6   295.328  426000.0  401254.775442
# 2022-07-02          5.70          5.6   295.328  420000.0  396903.773679
# 2022-07-09          5.30          5.6   295.271  420000.0  396903.773679
#
# [735 rows x 5 columns]

# %%
price_data.columns=['interest', 'vacancy','cpi','price','value',]

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value
# 2008-02-02      5.68     10.1  212.174  144250.0  157110.334849
# 2008-02-09      5.67     10.1  212.687  148900.0  157110.334849
# 2008-02-16      5.72     10.1  212.687  139000.0  157110.334849
# 2008-02-23      6.04     10.1  212.687  143700.0  157110.334849
# 2008-03-01      6.24     10.1  212.687  145900.0  157027.222613
# ...              ...      ...      ...       ...            ...
# 2022-06-11      5.23      5.6  295.328  425000.0  401254.775442
# 2022-06-18      5.78      5.6  295.328  427750.0  401254.775442
# 2022-06-25      5.81      5.6  295.328  426000.0  401254.775442
# 2022-07-02      5.70      5.6  295.328  420000.0  396903.773679
# 2022-07-09      5.30      5.6  295.271  420000.0  396903.773679
#
# [735 rows x 5 columns]

# %%
price_data.plot.line(y='price', use_index=True)
# Out:
# <AxesSubplot:>

# %%
price_data['adj_price']= price_data['price']/ price_data['cpi']*100

# %%
price_data.plot.line(y='adj_price', use_index=True)
# Out:
# <AxesSubplot:>

# %%
price_data['adj_value'] = price_data['value']/ price_data['cpi']*100

# %%
price_data['next_quarter'] = price_data['adj_price'].shift(-13)

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-02      5.68     10.1  212.174  144250.0  157110.334849
# 2008-02-09      5.67     10.1  212.687  148900.0  157110.334849
# 2008-02-16      5.72     10.1  212.687  139000.0  157110.334849
# 2008-02-23      6.04     10.1  212.687  143700.0  157110.334849
# 2008-03-01      6.24     10.1  212.687  145900.0  157027.222613
# ...              ...      ...      ...       ...            ...
# 2022-06-11      5.23      5.6  295.328  425000.0  401254.775442
# 2022-06-18      5.78      5.6  295.328  427750.0  401254.775442
# 2022-06-25      5.81      5.6  295.328  426000.0  401254.775442
# 2022-07-02      5.70      5.6  295.328  420000.0  396903.773679
# 2022-07-09      5.30      5.6  295.271  420000.0  396903.773679
#
#                 adj_price      adj_value  next_quarter
# 2008-02-02   67986.652464   74047.873372  72952.678339
# 2008-02-09   70008.980333   73869.270265  70629.344634
# 2008-02-16   65354.252963   73869.270265  67376.677447
# 2008-02-23   67564.073028   73869.270265   71210.17806
# 2008-03-01   68598.456887   73830.193013  76205.345526
# ...                   ...            ...           ...
# 2022-06-11   143907.79066  135867.501707           NaN
# 2022-06-18  144838.958717  135867.501707           NaN
# 2022-06-25  144246.397226  135867.501707           NaN
# 2022-07-02  142214.757829  134394.223941           NaN
# 2022-07-09  142242.211392  134420.167805           NaN
#
# [735 rows x 8 columns]

# %%
price_data.dropna(inplace=True)

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-02      5.68     10.1  212.174  144250.0  157110.334849
# 2008-02-09      5.67     10.1  212.687  148900.0  157110.334849
# 2008-02-16      5.72     10.1  212.687  139000.0  157110.334849
# 2008-02-23      6.04     10.1  212.687  143700.0  157110.334849
# 2008-03-01      6.24     10.1  212.687  145900.0  157027.222613
# ...              ...      ...      ...       ...            ...
# 2022-03-12      3.85      5.8  287.708  390000.0  376522.090399
# 2022-03-19      4.16      5.8  287.708  388000.0  376522.090399
# 2022-03-26      4.42      5.8  287.708  386500.0  376522.090399
# 2022-04-02      4.67      5.8  287.708  401911.0  391696.585402
# 2022-04-09      4.72      5.6  288.663  418900.0  391696.585402
#
#                 adj_price      adj_value   next_quarter
# 2008-02-02   67986.652464   74047.873372   72952.678339
# 2008-02-09   70008.980333   73869.270265   70629.344634
# 2008-02-16   65354.252963   73869.270265   67376.677447
# 2008-02-23   67564.073028   73869.270265    71210.17806
# 2008-03-01   68598.456887   73830.193013   76205.345526
# ...                   ...            ...            ...
# 2022-03-12  135554.103466  130869.524101   143907.79066
# 2022-03-19  134858.954217  130869.524101  144838.958717
# 2022-03-26  134337.592281  130869.524101  144246.397226
# 2022-04-02  139694.064816    136143.7935  142214.757829
# 2022-04-09  145117.316733  135693.381348  142242.211392
#
# [722 rows x 8 columns]

# %%
price_data['change'] = (price_data['next_quarter'] > price_data['adj_price']).astype(int)

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-02      5.68     10.1  212.174  144250.0  157110.334849
# 2008-02-09      5.67     10.1  212.687  148900.0  157110.334849
# 2008-02-16      5.72     10.1  212.687  139000.0  157110.334849
# 2008-02-23      6.04     10.1  212.687  143700.0  157110.334849
# 2008-03-01      6.24     10.1  212.687  145900.0  157027.222613
# ...              ...      ...      ...       ...            ...
# 2022-03-12      3.85      5.8  287.708  390000.0  376522.090399
# 2022-03-19      4.16      5.8  287.708  388000.0  376522.090399
# 2022-03-26      4.42      5.8  287.708  386500.0  376522.090399
# 2022-04-02      4.67      5.8  287.708  401911.0  391696.585402
# 2022-04-09      4.72      5.6  288.663  418900.0  391696.585402
#
#                 adj_price      adj_value   next_quarter  change
# 2008-02-02   67986.652464   74047.873372   72952.678339       1
# 2008-02-09   70008.980333   73869.270265   70629.344634       1
# 2008-02-16   65354.252963   73869.270265   67376.677447       1
# 2008-02-23   67564.073028   73869.270265    71210.17806       1
# 2008-03-01   68598.456887   73830.193013   76205.345526       1
# ...                   ...            ...            ...     ...
# 2022-03-12  135554.103466  130869.524101   143907.79066       1
# 2022-03-19  134858.954217  130869.524101  144838.958717       1
# 2022-03-26  134337.592281  130869.524101  144246.397226       1
# 2022-04-02  139694.064816    136143.7935  142214.757829       1
# 2022-04-09  145117.316733  135693.381348  142242.211392       0
#
# [722 rows x 9 columns]

# %%
price_data['change'].value_counts()
# Out:
# 1    408
# 0    314
# Name: change, dtype: int64

# %%
predictors = ['interest','vacancy','adj_price', 'adj_value']
target = 'change'

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

# %%
START = 260
STEP = 52
def predict(train,test, predictors,target):
    rf = RandomForestClassifier(random_state=1)
    rf.fit(train[predictors],train[target])
    preds= rf.predict(test[predictors])
    return preds

def backtest(data,predictors,target):
    all_preds = []
    for i in range(START, data.shape[0],STEP):
        train = price_data.iloc[:i]
        test = price_data.iloc[i:(i+STEP)]
        all_preds.append(predict(train,test,predictors,target))
    preds = np.concatenate(all_preds)
    return preds, accuracy_score(data.iloc[START:][target], preds)

# %%
preds,accuracy = backtest(price_data, predictors,target)

# %%
accuracy
# Out:
# 0.5952380952380952

# %%
yearly = price_data.rolling(52, min_periods=1).mean()

# %%
yearly
# Out:
#             interest    vacancy         cpi          price          value  \
# 2008-02-02  5.680000  10.100000  212.174000  144250.000000  157110.334849
# 2008-02-09  5.675000  10.100000  212.430500  146575.000000  157110.334849
# 2008-02-16  5.690000  10.100000  212.516000  144050.000000  157110.334849
# 2008-02-23  5.777500  10.100000  212.558750  143962.500000  157110.334849
# 2008-03-01  5.870000  10.100000  212.584400  144350.000000  157093.712402
# ...              ...        ...         ...            ...            ...
# 2022-03-12  3.115000   5.934615  274.619904  352828.211538  331507.120230
# 2022-03-19  3.136923   5.915385  275.056058  354039.750000  333154.394213
# 2022-03-26  3.163269   5.896154  275.492212  355491.673077  334801.668196
# 2022-04-02  3.193654   5.876923  275.928365  357163.038462  336740.759391
# 2022-04-09  3.223462   5.853846  276.382885  358970.730769  338679.850586
#
#                 adj_price      adj_value   next_quarter    change
# 2008-02-02   67986.652464   74047.873372   72952.678339  1.000000
# 2008-02-09   68997.816399   73958.571819   71791.011487  1.000000
# 2008-02-16   67783.295253   73928.804634   70319.566807  1.000000
# 2008-02-23   67728.489697   73913.921042   70542.219620  1.000000
# 2008-03-01   67902.483135   73897.175436   71674.844801  1.000000
# ...                   ...            ...            ...       ...
# 2022-03-12  128432.784926  120574.814229  133111.380121  0.673077
# 2022-03-19  128667.984960  120980.990753  133370.069121  0.673077
# 2022-03-26  128994.744586  121387.167278  133642.203620  0.673077
# 2022-04-02  129395.488790  121894.772061  133857.524622  0.673077
# 2022-04-09  129828.690638  122393.715071  134179.834627  0.653846
#
# [722 rows x 9 columns]

# %%
yearly_ratios = [p+'_year' for p in predictors]
price_data[yearly_ratios] = price_data[predictors]/ yearly[predictors]

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-02      5.68     10.1  212.174  144250.0  157110.334849
# 2008-02-09      5.67     10.1  212.687  148900.0  157110.334849
# 2008-02-16      5.72     10.1  212.687  139000.0  157110.334849
# 2008-02-23      6.04     10.1  212.687  143700.0  157110.334849
# 2008-03-01      6.24     10.1  212.687  145900.0  157027.222613
# ...              ...      ...      ...       ...            ...
# 2022-03-12      3.85      5.8  287.708  390000.0  376522.090399
# 2022-03-19      4.16      5.8  287.708  388000.0  376522.090399
# 2022-03-26      4.42      5.8  287.708  386500.0  376522.090399
# 2022-04-02      4.67      5.8  287.708  401911.0  391696.585402
# 2022-04-09      4.72      5.6  288.663  418900.0  391696.585402
#
#                 adj_price      adj_value   next_quarter  change  \
# 2008-02-02   67986.652464   74047.873372   72952.678339       1
# 2008-02-09   70008.980333   73869.270265   70629.344634       1
# 2008-02-16   65354.252963   73869.270265   67376.677447       1
# 2008-02-23   67564.073028   73869.270265    71210.17806       1
# 2008-03-01   68598.456887   73830.193013   76205.345526       1
# ...                   ...            ...            ...     ...
# 2022-03-12  135554.103466  130869.524101   143907.79066       1
# 2022-03-19  134858.954217  130869.524101  144838.958717       1
# 2022-03-26  134337.592281  130869.524101  144246.397226       1
# 2022-04-02  139694.064816    136143.7935  142214.757829       1
# 2022-04-09  145117.316733  135693.381348  142242.211392       0
#
#             interest_year  vacancy_year adj_price_year adj_value_year
# 2008-02-02       1.000000      1.000000            1.0            1.0
# 2008-02-09       0.999119      1.000000       1.014655       0.998793
# 2008-02-16       1.005272      1.000000       0.964165       0.999195
# 2008-02-23       1.045435      1.000000       0.997572       0.999396
# 2008-03-01       1.063032      1.000000        1.01025       0.999094
# ...                   ...           ...            ...            ...
# 2022-03-12       1.235955      0.977317       1.055448        1.08538
# 2022-03-19       1.326140      0.980494       1.048116       1.081736
# 2022-03-26       1.397289      0.983692       1.041419       1.078117
# 2022-04-02       1.462275      0.986911        1.07959       1.116896
# 2022-04-09       1.464264      0.956636        1.11776       1.108663
#
# [722 rows x 13 columns]

# %%
preds, accuracy = backtest(price_data, predictors+ yearly_ratios,target)

# %%
accuracy
# Out:
# 0.6103896103896104

# %%
pred_match = (preds== price_data[target].iloc[START:])

# %%
pred_match[pred_match == True]= 'green'
pred_match[pred_match == False]= 'red'

# %%
import matplotlib.pyplot as plt

plot_data = price_data.iloc[START:].copy()

plot_data.reset_index().plot.scatter(x='index', y='adj_price', color=pred_match)
# Out:
# <AxesSubplot:xlabel='index', ylabel='adj_price'>

# %%
from sklearn.inspection import permutation_importance

rf = RandomForestClassifier(min_samples_split=10, random_state=1)
rf.fit(price_data[predictors], price_data[target])

result = permutation_importance(rf, price_data[predictors],price_data[target],n_repeats=10, random_state=1)

# %%
result['importances_mean']
# Out:
# array([0.15858726, 0.17451524, 0.30858726, 0.25277008])

# %%
predictors
# Out:
# ['interest', 'vacancy', 'adj_price', 'adj_value']

# %% [markdown]
# Addtional Info to add in model

# %%
#Add stock market indicators
# Info on gold
# News articles on housing prices,. new development, natural disaters etc
